# %% [markdown]
# # Mergers & Acquisitions Data

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting Theme
# ### - Colorblind - Friendly

# %%
sns.color_palette("colorblind")
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %% [markdown]
# ## Exploratory Data Analysis (and data cleaning)

# %% [markdown]
# ### Reading data file

# %%
data_df = pd.read_csv("acquisitions_update_2021.csv")

# %% [markdown]
# ### Number of (Rows, Columns) in the data

# %%
data_df.shape
# Out:
# (1455, 10)

# %% [markdown]
# ### What are the column names?

# %%
data_df.columns
# Out:
# Index(['ID', 'Parent Company', 'Acquisition Year', 'Acquisition Month',
#        'Acquired Company', 'Business', 'Country', 'Acquisition Price',
#        'Category', 'Derived Products'],
#       dtype='object')

# %% [markdown]
# ### Looking at the first 5 rows

# %%
data_df.head(5)
# Out:
#    ID Parent Company Acquisition Year Acquisition Month  \
# 0   1          Apple             1988               Mar
# 1   2          Apple             1988               Jun
# 2   3          Apple             1988               Jun
# 3   4          Apple             1988               Jul
# 4   5          Apple             1989               Jan
#
#         Acquired Company           Business Country Acquisition Price  \
# 0    Network Innovations           Software       -                 -
# 1  Orion Network Systems  Computer Software       -                 -
# 2              Styleware  Computer software       -                 -
# 3        Nashoba Systems  Computer software       -                 -
# 4         Coral Software  Computer software       -                 -
#
#   Category Derived Products
# 0        -                -
# 1        -                -
# 2        -                -
# 3        -                -
# 4        -                -

# %% [markdown]
# ### Replacing "-" with NaN values

# %%
data_cleaned = data_df.replace("-", np.nan)

# %% [markdown]
# ### Recheck data

# %%
data_cleaned.head()
# Out:
#    ID Parent Company Acquisition Year Acquisition Month  \
# 0   1          Apple             1988               Mar
# 1   2          Apple             1988               Jun
# 2   3          Apple             1988               Jun
# 3   4          Apple             1988               Jul
# 4   5          Apple             1989               Jan
#
#         Acquired Company           Business Country Acquisition Price  \
# 0    Network Innovations           Software     NaN               NaN
# 1  Orion Network Systems  Computer Software     NaN               NaN
# 2              Styleware  Computer software     NaN               NaN
# 3        Nashoba Systems  Computer software     NaN               NaN
# 4         Coral Software  Computer software     NaN               NaN
#
#   Category Derived Products
# 0      NaN              NaN
# 1      NaN              NaN
# 2      NaN              NaN
# 3      NaN              NaN
# 4      NaN              NaN

# %% [markdown]
# ### Which columns contain missing/ NaN values?

# %%
data_cleaned.isna().any()
# Out:
# ID                   False
# Parent Company       False
# Acquisition Year      True
# Acquisition Month     True
# Acquired Company     False
# Business              True
# Country               True
# Acquisition Price     True
# Category              True
# Derived Products      True
# dtype: bool

# %%
data_cleaned.Country.count()
# Out:
# 341

# %% [markdown]
# ### Type of Data for each column

# %%
data_df.dtypes
# Out:
# ID                    int64
# Parent Company       object
# Acquisition Year     object
# Acquisition Month    object
# Acquired Company     object
# Business             object
# Country              object
# Acquisition Price    object
# Category             object
# Derived Products     object
# dtype: object

# %% [markdown]
# ### Convert Year and Price to "int" from "objects"

# %%
data_cleaned["Acquisition Year"] = pd.to_numeric(
    data_cleaned["Acquisition Year"])
data_cleaned['Acquisition Price'] = pd.to_numeric(
    data_cleaned['Acquisition Price'], errors='coerce')

# %% [markdown]
# ### Finally; some brief overview of the data

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1455 entries, 0 to 1454
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1455 non-null   int64
#  1   Parent Company     1455 non-null   object
#  2   Acquisition Year   1427 non-null   float64
#  3   Acquisition Month  1397 non-null   object
#  4   Acquired Company   1455 non-null   object
#  5   Business           1181 non-null   object
#  6   Country            341 non-null    object
#  7   Acquisition Price  383 non-null    float64
#  8   Category           10 non-null     object
#  9   Derived Products   403 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 113.8+ KB

# %% [markdown]
# ### What's the range of numerical values?

# %%
data_cleaned.describe()
# Out:
#                 ID  Acquisition Year  Acquisition Price
# count  1455.000000       1427.000000       3.830000e+02
# mean    728.000000       2009.676945       1.357384e+09
# std     420.166634          8.056344       5.526084e+09
# min       1.000000       1957.000000       2.000000e+05
# 25%     364.500000       2006.000000       4.725000e+07
# 50%     728.000000       2011.000000       1.510000e+08
# 75%    1091.500000       2015.000000       5.500000e+08
# max    1455.000000       2021.000000       7.130000e+10

# %% [markdown]
# ### "month" column data integrity check

# %%
data_cleaned["Acquisition Month"].unique()
# Out:
# array(['Mar', 'Jun', 'Jul', 'Jan', 'Feb', 'Sep', 'Nov', 'Apr', nan, 'May',
#        'Dec', 'Oct', 'Aug'], dtype=object)

# %% [markdown]
# ## Data Visualization and Statistical Analysis

# %% [markdown]
# ### Acquisitions through the years

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Acquisitions over the years", fontsize=30, fontweight="bold")
plt.xlabel("Acquisition Year", fontsize=25)
plt.ylabel("Companies Acquired", fontsize=25)
sns.histplot(data=data_cleaned, x="Acquisition Year", kde=True, bins=25,
             color="navy")
sns.despine(offset=15, trim=False)

# %% [markdown]
# ### Is there a particular time of the year when companies are acquired?

# %%
data_cleaned['Acquisition Month'] = pd.Categorical(data_cleaned['Acquisition Month'], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug',
                                                                                       'Sep', 'Oct', 'Nov',
                                                                                       'Dec'])

plt.figure(figsize=(10, 5))
sns.set_style("ticks")
plt.title("Do Companies Prefer A particular month? ",
          fontsize=30, fontweight="bold")
plt.xlabel("Acquisition Month", fontsize=25)
plt.ylabel("Companies Acquired (%)", fontsize=25)
sns.histplot(data=data_cleaned, x="Acquisition Month", hue="Acquisition Month", stat="percent",
             legend=False, palette="colorblind")
sns.despine(offset=15, trim=False)

# %% [markdown]
# ### Most Acquisitions by comapnies

# %%
companies = data_cleaned["Parent Company"].value_counts().reset_index()
companies = companies.rename(
    {"index": "Company", "Parent Company": "Acquired Companies"}, axis=1)
companies
# Out:
#        Company  Acquired Companies
# 0    Microsoft                 258
# 1       Google                 244
# 2          Ibm                 182
# 3           Hp                 129
# 4        Apple                 123
# 5       Amazon                 108
# 6     Facebook                  93
# 7      Twitter                  65
# 8         Ebay                  63
# 9        Adobe                  52
# 10      Citrix                  52
# 11      Redhat                  35
# 12  Blackberry                  32
# 13      Disney                  19

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Most Companies Acquired", fontsize=30, fontweight="bold")
plt.xlabel("Acquisition Year", fontsize=25)
plt.ylabel("Companies Acquired", fontsize=25)
sns.barplot(data=companies, x="Company",
            y="Acquired Companies", palette="colorblind")
sns.despine(offset=15, trim=True)

# %% [markdown]
# ### Was there a Company Acquired Multiple times?

# %%
data_cleaned["Acquired Company"].value_counts().head()
# Out:
# Disneyland, Inc.       2
# Wrather Corporation    2
# Magento                2
# Blackthorne            1
# mobile.de              1
# Name: Acquired Company, dtype: int64

# %% [markdown]
# ### Most common types of businesses acquired

# %%
business_types = data_cleaned["Business"].value_counts().reset_index()
business_types = business_types.rename(
    {"index": "Business", "Business": "Number of Companies"}, axis=1)
business_types = business_types.head(25)
business_types
# Out:
#                               Business  Number of Companies
# 0                             Software                   52
# 1                    Computer software                   37
# 2                          Video games                   18
# 3               Information technology                   15
# 4                    Internet software                   12
# 5               Classified advertising                    8
# 6    Information technology consulting                    7
# 7                  Electronic commerce                    7
# 8                       Online auction                    6
# 9              Artificial intelligence                    6
# 10                  Online advertising                    6
# 11                    Machine learning                    6
# 12                         IT Services                    5
# 13           Internet service provider                    5
# 14                                Maps                    5
# 15                     Mobile software                    5
# 16               Business Intelligence                    4
# 17            Mobile device management                    4
# 18                         Advertising                    4
# 19            Automatic test equipment                    4
# 20                   Computer security                    4
# 21           Social networking service                    4
# 22                     Cloud computing                    4
# 23  Enterprise Information Integration                    4
# 24                     Music streaming                    4

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Most Common Types of Businesses Acquired",
          fontsize=30, fontweight="bold")
plt.xlabel("No. of Companies", fontsize=25)
plt.ylabel("Type of Business", fontsize=25)
sns.barplot(data=business_types, x="Number of Companies",
            y="Business", palette="colorblind")
sns.despine(offset=20, trim=True)

# %% [markdown]
# ### Does the "Category" variable have any significance?

# %%
data_cleaned.Category.value_counts()
# Out:
# Twitter Cortex              2
# Mobile Twitter app (iOS)    1
# Analytics tools             1
# Revenue team                1
# Revenue engineering team    1
# Design                      1
# MoPub                       1
# Commerce                    1
# Twitter Spaces              1
# Name: Category, dtype: int64

# %% [markdown]
# ### What do acquired companies end up as most?

# %%
new_products = data_cleaned["Derived Products"].value_counts().reset_index()
new_products = new_products.rename(
    {"index": "Derived Product", "Derived Products": "Number of Companies"}, axis=1)
new_products = new_products.head(25)
new_products
# Out:
#           Derived Product  Number of Companies
# 0   Google Cloud Platform                   22
# 1                 Android                   19
# 2     Amazon Web Services                   17
# 3                 YouTube                   12
# 4                       X                    9
# 5             Google Maps                    9
# 6                 Google+                    7
# 7             Google Docs                    7
# 8           Oculus Studio                    5
# 9         Google Shopping                    5
# 10              Nest Labs                    5
# 11          Google Mobile                    5
# 12          Google Offers                    5
# 13                AdSense                    4
# 14     Twitch Interactive                    4
# 15          Google Photos                    3
# 16           Project Zero                    3
# 17                Blogger                    3
# 18        Amazon Robotics                    3
# 19     Facebook Messenger                    3
# 20              ShareFile                    3
# 21          Google Search                    3
# 22  Facebook Reality Labs                    3
# 23          Amazon Kindle                    3
# 24                  Gmail                    3

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Most Common Products Derived from Acquisitions",
          fontsize=30, fontweight="bold")
plt.xlabel("No. of Companies", fontsize=25)
plt.ylabel("Type of Business", fontsize=25)
sns.barplot(data=new_products, y="Derived Product",
            x="Number of Companies", palette="colorblind")
sns.despine(offset=20, trim=True)

# %% [markdown]
# ### Where do most acquisitions happen?

# %%
countries = data_cleaned["Country"].value_counts().reset_index()
countries = countries.rename(
    {"index": "Country", "Country": "Number of Companies"}, axis=1)
countries = countries.head(25)
countries
# Out:
#            Country  Number of Companies
# 0    United States                  248
# 1   United Kingdom                   17
# 2           Canada                   14
# 3          Ireland                    9
# 4          Germany                    7
# 5           Israel                    6
# 6           France                    5
# 7        Australia                    5
# 8            India                    4
# 9           Sweden                    2
# 10           Spain                    2
# 11         Finland                    2
# 12           Italy                    2
# 13       Singapore                    2
# 14     Netherlands                    2
# 15          Brazil                    2
# 16     Switzerland                    2
# 17         Denmark                    2
# 18     New Zealand                    2
# 19       Hong Kong                    1
# 20          Norway                    1
# 21     South Korea                    1
# 22        Malaysia                    1
# 23         Belarus                    1
# 24  Czech Republic                    1

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Countries with most acquisitions",
          fontsize=30, fontweight="bold")
sns.barplot(data=countries, y="Country",
            x="Number of Companies", palette="colorblind")

plt.xlabel("No. of Companies", fontsize=25)
plt.ylabel("", fontsize=25)
sns.despine(offset=20, trim=True)

# %% [markdown]
# ### Whats the average cost of acquiring a company?

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
plt.title("Average Price of Acquisition", fontsize=30, fontweight="bold")
plt.xlabel("Acquisition Price (in 10 billion)", fontsize=25)
plt.ylabel("Companies Acquired", fontsize=25)
sns.histplot(data=data_cleaned, x="Acquisition Price", kde=True, bins=150,
             color="navy")
plt.xlim(0, 5e10)

sns.despine(offset=15, trim=False)

# %% [markdown]
# ### Top 10 most expensive acquisitions

# %%
most_valuable = data_cleaned.sort_values(
    "Acquisition Price", ascending=False).head(10)
most_valuable
# Out:
#         ID Parent Company  Acquisition Year Acquisition Month  \
# 1402  1403         Disney            2019.0               Mar
# 168    169        Twitter            2015.0               Mar
# 1190  1191            Ibm            2019.0               Jul
# 872    873      Microsoft            2016.0               Dec
# 350    351             Hp            2002.0               May
# 917    918      Microsoft            2021.0               Apr
# 1303  1304       Facebook            2014.0               Feb
# 1390  1391         Disney            1996.0               Feb
# 396    397             Hp            2008.0               Aug
# 267    268         Amazon            2017.0               Jun
#
#              Acquired Company                                        Business  \
# 1402         21st Century Fox                                             NaN
# 168                 Periscope                            Live-video streaming
# 1190                  Red Hat  Provider of open source software and solutions
# 872                  LinkedIn                     Professional social network
# 350                    Compaq                               Personal computer
# 917     Nuance Communications         Speech synthesis and speech recognition
# 1303                 WhatsApp                                             NaN
# 1390  Capital Cities/ABC Inc.                                             NaN
# 396   Electronic Data Systems               Information technology consulting
# 267        Whole Foods Market                                             NaN
#
#             Country  Acquisition Price Category    Derived Products
# 1402            NaN       7.130000e+10      NaN                 NaN
# 168             NaN       5.010000e+10      NaN                 NaN
# 1190  United States       3.400000e+10      NaN                 NaN
# 872             NaN       2.620000e+10      NaN                 NaN
# 350             NaN       2.500000e+10      NaN                 NaN
# 917             NaN       1.970000e+10      NaN                 NaN
# 1303  United States       1.900000e+10      NaN                 NaN
# 1390            NaN       1.900000e+10      NaN                 NaN
# 396             NaN       1.390000e+10      NaN                 NaN
# 267             NaN       1.370000e+10      NaN  Whole Foods Market

# %% [markdown]
# ### Most expensive companies and who acquired them

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Most Expensive Acquisitions",
          fontsize=30, fontweight="bold")
ax = sns.barplot(data=most_valuable, x="Acquired Company",
                 y="Acquisition Price", palette="colorblind")
for bar, label in zip(ax.patches, most_valuable['Parent Company']):
    x = bar.get_x()
    width = bar.get_width()
    height = bar.get_height()
    ax.text(x+width/2., height + 0.1e10, label,
            ha="center", fontsize=15, fontweight="bold")

plt.ylabel("Price (in $10 billion)", fontsize=25)
plt.xlabel("")
ax.tick_params(axis="x", labelsize=12, rotation=90)
sns.despine(offset=20, trim=True)

# %% [markdown]
# ### What does each company spend on average on an acquisition?

# %%
average_spend = data_cleaned.groupby(['Parent Company']).mean(
).reset_index().sort_values("Acquisition Price", ascending=False)
average_spend
# Out:
#    Parent Company      ID  Acquisition Year  Acquisition Price
# 5          Disney  1394.0       1996.368421       8.137547e+09
# 13        Twitter   156.0       2013.984615       3.695226e+09
# 9              Hp   361.0       1999.891089       2.236599e+09
# 10            Ibm  1113.5       2010.109890       1.849158e+09
# 11      Microsoft   798.5       2008.445736       1.660034e+09
# 0           Adobe  1230.5       2006.365385       1.191624e+09
# 7        Facebook  1303.0       2014.258065       9.332577e+08
# 1          Amazon   242.5       2011.592593       8.416872e+08
# 6            Ebay   991.0       2008.317460       4.493438e+08
# 3      Blackberry   943.5       2010.312500       3.023906e+08
# 8          Google   547.5       2012.188525       1.727388e+08
# 12         Redhat  1367.0       2008.285714       1.578747e+08
# 2           Apple    62.0       2011.837398       1.343853e+08
# 4          Citrix  1429.5       2009.192308                NaN

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Average Acquisition Cost for companies",
          fontsize=30, fontweight="bold")
sns.barplot(data=average_spend, y="Parent Company",
            x="Acquisition Price", palette="colorblind")

plt.xlabel("Cost (in Billions)", fontsize=25)
plt.ylabel("", fontsize=25)
sns.despine(offset=20, trim=True)

# %% [markdown]
# ### Has the price of acquiring a company changed over the years?

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")

plt.title("Acquisition Price over the years",
          fontsize=30, fontweight="bold")
sns.lineplot(data=data_cleaned, x='Acquisition Year',
             y='Acquisition Price')

sns.scatterplot(data=data_cleaned, x='Acquisition Year',
             y='Acquisition Price', palette="colorblind")
plt.ylabel("Cost (in Billions)", fontsize=25)
plt.xlabel("Year", fontsize=25)
sns.despine(offset=20, trim=False)

# %% [markdown]
# ### Rate of Acquisition

# %% [markdown]
# #### Number of years company has actively acquired other companies

# %%
years_active = data_cleaned.groupby(
    ['Parent Company', 'Acquisition Year']).count().reset_index()
years_active = years_active.groupby(['Parent Company']).count()
years_active
# Out:
#                 Acquisition Year  ID  Acquisition Month  Acquired Company  \
# Parent Company
# Adobe                         26  26                 26                26
# Amazon                        21  21                 21                21
# Apple                         23  23                 23                23
# Blackberry                    13  13                 13                13
# Citrix                        21  21                 21                21
# Disney                        18  18                 18                18
# Ebay                          22  22                 22                22
# Facebook                      16  16                 16                16
# Google                        20  20                 20                20
# Hp                            35  35                 35                35
# Ibm                           21  21                 21                21
# Microsoft                     31  31                 31                31
# Redhat                        18  18                 18                18
# Twitter                       13  13                 13                13
#
#                 Business  Country  Acquisition Price  Category  \
# Parent Company
# Adobe                 26       26                 26        26
# Amazon                21       21                 21        21
# Apple                 23       23                 23        23
# Blackberry            13       13                 13        13
# Citrix                21       21                 21        21
# Disney                18       18                 18        18
# Ebay                  22       22                 22        22
# Facebook              16       16                 16        16
# Google                20       20                 20        20
# Hp                    35       35                 35        35
# Ibm                   21       21                 21        21
# Microsoft             31       31                 31        31
# Redhat                18       18                 18        18
# Twitter               13       13                 13        13
#
#                 Derived Products
# Parent Company
# Adobe                         26
# Amazon                        21
# Apple                         23
# Blackberry                    13
# Citrix                        21
# Disney                        18
# Ebay                          22
# Facebook                      16
# Google                        20
# Hp                            35
# Ibm                           21
# Microsoft                     31
# Redhat                        18
# Twitter                       13

# %% [markdown]
# #### Number of Companies Acquired

# %%
total_acquisitions = data_cleaned.groupby('Parent Company').count()
total_acquisitions
# Out:
#                  ID  Acquisition Year  Acquisition Month  Acquired Company  \
# Parent Company
# Adobe            52                52                 51                52
# Amazon          108               108                106               108
# Apple           123               123                114               123
# Blackberry       32                32                 32                32
# Citrix           52                52                 51                52
# Disney           19                19                 11                19
# Ebay             63                63                 63                63
# Facebook         93                93                 93                93
# Google          244               244                243               244
# Hp              129               101                 93               129
# Ibm             182               182                182               182
# Microsoft       258               258                258               258
# Redhat           35                35                 35                35
# Twitter          65                65                 65                65
#
#                 Business  Country  Acquisition Price  Category  \
# Parent Company
# Adobe                  0        0                 14         0
# Amazon                 0        0                 39         0
# Apple                123        0                 39         0
# Blackberry            32        0                  8         0
# Citrix                51       47                  0         0
# Disney                 0        0                 14         0
# Ebay                  63        0                 32         0
# Facebook               0       90                 26         0
# Google               244        0                 49         0
# Hp                   129        1                 34         0
# Ibm                  182      180                 38         0
# Microsoft            258        0                 61         0
# Redhat                35        0                 15         0
# Twitter               64       23                 14        10
#
#                 Derived Products
# Parent Company
# Adobe                          0
# Amazon                        83
# Apple                          0
# Blackberry                     0
# Citrix                        52
# Disney                         0
# Ebay                           0
# Facebook                      30
# Google                       238
# Hp                             0
# Ibm                            0
# Microsoft                      0
# Redhat                         0
# Twitter                        0

# %% [markdown]
# ### Acquisition Rate for each company per year

# %%
acquisition_rate = pd.DataFrame(
    {'years': years_active['Acquisition Year'], 'acquired companies': total_acquisitions['Acquired Company']})
acquisition_rate = acquisition_rate['acquired companies']/acquisition_rate['years']
acquisition_rate = acquisition_rate.reset_index()

acquisition_rate= acquisition_rate.rename(
    {"Parent Comapny": "Company", 0: "Average Acquisitions"}, axis=1).sort_values("Average Acquisitions", ascending= False)
acquisition_rate
# Out:
#    Parent Company  Average Acquisitions
# 8          Google             12.200000
# 10            Ibm              8.666667
# 11      Microsoft              8.322581
# 7        Facebook              5.812500
# 2           Apple              5.347826
# 1          Amazon              5.142857
# 13        Twitter              5.000000
# 9              Hp              3.685714
# 6            Ebay              2.863636
# 4          Citrix              2.476190
# 3      Blackberry              2.461538
# 0           Adobe              2.000000
# 12         Redhat              1.944444
# 5          Disney              1.055556

# %%
plt.figure(figsize=(20, 10))
sns.set_style("ticks")
plt.title("Average Acquisitions each year",
          fontsize=30, fontweight="bold")
sns.barplot(data=acquisition_rate, y="Parent Company",
            x="Average Acquisitions", palette="colorblind")

plt.xlabel("Companies per year", fontsize=25)
plt.ylabel("", fontsize=25)
sns.despine(offset=20, trim=True)
